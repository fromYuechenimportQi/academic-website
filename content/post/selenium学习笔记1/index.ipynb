# %% [markdown]
# ---
# title: Selenium学习笔记1
# subtitle: Selenium最佳实践
# summary: 爬虫学习
# authors:
# - admin
# tags: [爬虫]
# categories: [爬虫]
# date: "2023-07-18T00:00:00Z"
# lastMod: "2023-07-18T00:00:00Z"
# featured: false
# draft: false
#
# # Featured image
# # To use, add an image named `featured.jpg/png` to your page's folder.
# image:
#   caption: ""
#   focal_point: ""
#
# # Projects (optional).
# #   Associate this post with one or more of your projects.
# #   Simply enter your project's folder or file name without extension.
# #   E.g. `projects = ["internal-project"]` references
# #   `content/project/deep-learning/index.md`.
# #   Otherwise, set `projects = []`.
# projects: []
# ---

# %% [markdown]
# ## 一、Selenium简介
#
# [Selenium](https://www.selenium.dev/zh-cn/documentation/webdriver/getting_started/)是一个网页自动化工具，提供了Java、Python和JS等语言的接口
#
# 在爬虫项目中，我们常常会遇到一个页面是通过JS渲染的，这就造成爬取html的不便
#
# 而Selenium可以模拟鼠标的操作，达到爬取的目的

# %% [markdown]
# ## 二、Selenium实践
#
# 以网站[Published Plant Genomes](https://www.plabipd.de/plant_genomes_pa.ep)为例，该网站前端页面非常漂亮，但是Published信息需要将鼠标移动到叶子(leaf)上才能显示，而该效果是通过JS渲染得到的，传统的beautifulSoup的HTML解析对此只能表示无能为力

# %%
url = 'https://www.plabipd.de/plant_genomes_pa.ep'

# %% [markdown]
# 测试Chrome浏览器能否打开

# %%
from selenium import webdriver
#初始化driver
diver = webdriver.Chrome()
#访问域名
diver.get(url)
#关闭浏览器
diver.close()

# %% [markdown]
# 找到所有的leaf

# %%
from selenium.webdriver.common.by import By
import time
driver = webdriver.Chrome()
driver.get(url)
##由于渲染是耗时操作，所以需要阻塞线程，等待渲染完成，这里等待5秒
time.sleep(5)
leaves = driver.find_elements(By.CLASS_NAME,'leaf')
for i in leaves:
    print(i.text)
driver.close()
# Out:
# Amborella trichopoda
# Euryale ferox
# Nymphaea colorata
# Nymphaea thermarum
# Aristolochia contorta
# Aristolochia fimbriata
# Piper nigrum
# Annona cherimola
# Annona glabra
# Annona muricata
# Liriodendron chinense
# Magnolia biondii
# Magnolia obovata
# Magnolia officinalis
# Chimonanthus praecox
# Chimonanthus salicifolius
# Cinnamomum camphora
# Cinnamomum kanehirae
# Lindera glauca
# Litsea coreana
# Litsea cubeba
# Persea americana
# Phoebe bournei
# Chloranthus sessilifolius
# Chloranthus spicatus
# Acorus calamus
# Acorus gramineus
# Lemna minor
# Lemna minuta
# Spirodela intermedia
# Spirodela polyrhiza
# Wolffia australiana
# Amorphophallus konjac
# Colocasia esculenta
# Pinellia pedatisecta
# Pistia stratiotes
# Zostera marina
# Zostera muelleri
# Acanthochlamys bracteata
# Xerophyta viscosa
# Dioscorea alata
# Dioscorea dumetorum
# Dioscorea rotundata
# Dioscorea zingiberensis
# Trichopus zeylanicus
# Apostasia ramifera
# Apostasia shenzhenica
# Bletilla striata
# Cremastra appendiculata
# Cymbidium crassifolium
# Cymbidium ensifolium
# Cymbidium goeringii
# Cymbidium sinense
# Dendrobium catenatum
# Dendrobium chrysotoxum
# Dendrobium huoshanense
# Dendrobium nobile
# Thlaspi arvense
# Tapiscia sinensis
# Atalantia buxifolia
# Citrus australis
# Citrus cavaleriei
# Citrus clementina
# Citrus japonica
# Citrus maxima
# Citrus medica
# Citrus polytrifolia
# Citrus reticulata
# Citrus sinensis
# Citrus trifoliata
# Citrus unshiu
# Citrus x aurantium
# Citrus x limon
# Clausena lansium
# Murraya paniculata
# Zanthoxylum armatum
# Zanthoxylum bungeanum
# Azadirachta indica
# Swietenia macrophylla
# Toona ciliata
# Toona sinensis
# Xylocarpus granatum
# Xylocarpus moluccensis
# Xylocarpus rumphii
# Anacardium occidentale
# Mangifera indica
# Pistacia chinensis
# Pistacia vera
# Toxicodendron vernicifluum
# Sclerocarya birrea
# Acer catalpifolium
# Acer negundo
# Acer palmatum
# Acer pseudosieboldianum
# Acer rubrum
# Acer saccharum
# Acer truncatum
# Acer yangbiense
# Aesculus chinensis
# Dimocarpus longan
# Litchi chinensis
# Nephelium lappaceum
# Sapindus mukorossi
# Xanthoceras sorbifolium
# Boswellia sacra
# Bursera bipinnata
# Bursera cuneata
# Bursera palmeri
# Commiphora wightii

# %% [markdown]
# 模拟鼠标操作

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
import time
driver = webdriver.Chrome()
driver.get(url)
#渲染耗时，因此阻塞，等待渲染完成，这里等待5秒
time.sleep(5)
#找到所有leaf元素
leaves = driver.find_elements(By.CLASS_NAME,'leaf')
for leaf in leaves[:5]:
    ActionChains(driver).move_to_element(leaf).perform()
    wait = WebDriverWait(driver, timeout=10,ignored_exceptions=TimeoutException)
    element = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'd3-tip')))
    print(element.get_attribute('innerHTML'))
    print('------------------')
driver.close()
# Out:
# <span> Amborella trichopoda</span><br>genome size: 748 Mbp<p class="refset"><span> published: 2013-12-20</span>Amborella Genome Project<br>The Amborella genome and the evolution of flowering plants.<br><a href="http://dx.doi.org/10.1126/science.1241089">Science. 2013 Dec 20 342(6165):1241089.</a></p>
# ------------------
# <span> Euryale ferox</span> <br>(Prickly waterlily)<br>genome size: 768 Mbp<p class="refset"><span> published: 2020-02-24</span>Yang Y et al.<br>Prickly waterlily and rigid hornwort genomes shed light on early angiosperm evolution.<br><a href="http://dx.doi.org/10.1038/s41477-020-0594-6">Nat Plants. 2020 Feb 24, Epub ahead of print</a></p>
# ------------------
# <span> Nymphaea colorata</span> <br>(Blue pigmy water lily)<br>genome size: 409 Mbp<p class="refset"><span> published: 2019-12-18</span>Zhang L et al.<br>The water lily genome and the early evolution of flowering plants.<br><a href="http://dx.doi.org/10.1038/s41586-019-1852-5">Nature. 2019 Dec 18, Epub ahead of print</a></p>
# ------------------
# <span> Nymphaea thermarum</span> <br>(Rwandan pigmy water lily)<br>genome size: 500 Mbp<p class="refset"><span> published: 2020-03-31</span>Povilus RA et al.<br>Water lily (Nymphaea thermarum) genome reveals variable genomic signatures of ancient vascular cambium losses.<br><a href="http://dx.doi.org/10.1073/pnas.1922873117">Proc Natl Acad Sci U S A. 2020 Mar 31, Epub ahead of print</a></p>
# ------------------
# <span> Aristolochia contorta</span> <br>(Northern pipevine)<br>genome size: 290 Mbp<p class="refset"><span> published: 2022-02-11</span>Cui X et al.<br>Chromosome-level genome assembly of Aristolochia contorta provides insights into the biosynthesis of benzylisoquinoline alkaloids and aristolochic acids.<br><a href="http://dx.doi.org/10.1093/hr/uhac005">Hortic Res. 2022 Feb 11: uhac005. Online ahead of print.</a></p>
# ------------------

# %% [markdown]
# 找到div.d3-tip后，其内部的html可以通过beautifulSoup4来解析，进而找到我们需要的所有信息！

# %% [markdown]
# 使用beautifulSoup4进行HTML的解析

# %%
from bs4 import BeautifulSoup
class Publication:
    def __init__(self,published_date=None,author=None,title=None,journal=None,doi=None):
        self.published_date = published_date
        self.author = author
        self.title = title
        self.journal = journal
        self.doi = doi
    def __str__(self):
        return f'发表日期:{self.published_date}\n作者:{self.author}\n标题:{self.title}\n期刊:{self.journal}\ndoi:{self.doi}'
class Paper:
        def __init__(self,species:str,genome_size:str,publication):
            self.species = species
            self.genome_size = genome_size
            self.publication = publication
        def __str__(self):
            return f'物种:{self.species}\n基因组大小:{self.genome_size}'
class PPGParser():
    def __init__(self,html):
        self.html = html
        self.soup = BeautifulSoup(html,'html.parser')
    def get_species(self):
        species = self.soup.find('span')
        return species.text.strip()
    def get_genome_size(self):
        genome_size = self.soup.find('p').previous_sibling.strip().split(':')[-1].strip()
        return genome_size
    def get_publish_information(self):
        result = []
        papers = self.soup.find_all('p',attrs={'class':'refset'})
        for paper in papers:
            publication = Publication()
            publication.published_date = paper.find('span').text.strip().split(':')[-1].strip()
            publication.author = paper.find('span').next_sibling.strip()
            publication.title = paper.find_all('br')[-1].previous_sibling.strip()
            publication.doi = paper.find('a').get('href')
            publication.journal = paper.find('a').text
            ##由于后续要输出一个excel，因此这里将publication对象转换为字典，之后json.loads方便转换为json
            result.append(publication.__dict__)
        return result
    def parse(self):
        species = self.get_species()
        genome_size = self.get_genome_size()
        publication = self.get_publish_information()
        paper = Paper(species,genome_size,publication)
        return paper
test = """
<span> Amborella trichopoda</span><br>genome size: 748 Mbp<p class="refset"><span> published: 2013-12-20</span>Amborella Genome Project<br>The Amborella genome and the evolution of flowering plants.<br><a href="http://dx.doi.org/10.1126/science.1241089">Science. 2013 Dec 20 342(6165):1241089.</a></p>
"""
ppg = PPGParser(test)
result = ppg.parse()
print(result)
for i in result.publication:
    print(i)
# Out:
# 物种:Amborella trichopoda
# 基因组大小:748 Mbp
# {'published_date': '2013-12-20', 'author': 'Amborella Genome Project', 'title': 'The Amborella genome and the evolution of flowering plants.', 'journal': 'Science. 2013 Dec 20 342(6165):1241089.', 'doi': 'http://dx.doi.org/10.1126/science.1241089'}

# %% [markdown]
# OK，经测试，爬取任务完成！
#
# 接下来便是保存数据啦，我们可以用pandas包，将结果写成一个excel~

# %%
import pandas as pd
import json
def save_PPG_as_excel(papers:list):
    df = pd.DataFrame(columns=['物种名','基因组大小','发表情况'])
    for paper in papers:
        #print(paper)
        df = df.append({'物种名':paper.species,'基因组大小':paper.genome_size,'发表情况':json.dumps(paper.publication,ensure_ascii=False)},ignore_index=True)
    df.to_excel('PPG.xlsx',index=False)

# %% [markdown]
# 那么综合所有代码块，达成最终目的！

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
url = 'https://www.plabipd.de/plant_genomes_pa.ep'
papers = []
driver = webdriver.Chrome()
driver.get(url)
#渲染耗时，因此阻塞，等待渲染完成，这里等待5秒
time.sleep(10)
#找到所有leaf元素
leaves = driver.find_elements(By.CLASS_NAME,'leaf')
for leaf in leaves:
    driver.execute_script(f"arguments[0].scrollIntoView();",leaf)
    ActionChains(driver).move_to_element(leaf).perform()
    wait = WebDriverWait(driver, timeout=10,ignored_exceptions=TimeoutException)
    element = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'd3-tip')))
    html = element.get_attribute('innerHTML')
    ppg = PPGParser(html)
    paper = ppg.parse()
    print(paper)
    papers.append(paper)
driver.close()
save_PPG_as_excel(papers)
# Out:
# 物种:Amborella trichopoda
# 基因组大小:748 Mbp
# 物种:Euryale ferox
# 基因组大小:768 Mbp
# 物种:Nymphaea colorata
# 基因组大小:409 Mbp
# 物种:Nymphaea thermarum
# 基因组大小:500 Mbp
# 物种:Aristolochia contorta
# 基因组大小:290 Mbp
# 物种:Aristolochia fimbriata
# 基因组大小:290 Mbp
# 物种:Piper nigrum
# 基因组大小:762 Mbp
# 物种:Annona cherimola
# 基因组大小:1130 Mbp
# 物种:Annona glabra
# 基因组大小:1050 Mbp
# 物种:Annona muricata
# 基因组大小:800 Mbp
# 物种:Liriodendron chinense
# 基因组大小:1750 Mbp
# 物种:Magnolia biondii
# 基因组大小:2240 Mbp
# 物种:Magnolia obovata
# 基因组大小:1700 Mbp
# 物种:Magnolia officinalis
# 基因组大小:1760 Mbp
# 物种:Chimonanthus praecox
# 基因组大小:780 Mbp
# 物种:Chimonanthus salicifolius
# 基因组大小:836 Mbp
# 物种:Cinnamomum camphora
# 基因组大小:790 Mbp
# 物种:Cinnamomum kanehirae
# 基因组大小:830 Mbp
# 物种:Lindera glauca
# 基因组大小:2200 Mbp
# 物种:Litsea coreana
# 基因组大小:1200 Mbp
# 物种:Litsea cubeba
# 基因组大小:1370 Mbp
# 物种:Persea americana
# 基因组大小:980 Mbp
# 物种:Phoebe bournei
# 基因组大小:1000 Mbp
# 物种:Chloranthus sessilifolius
# 基因组大小:2230 Mbp
# 物种:Chloranthus spicatus
# 基因组大小:3000 Mbp
# 物种:Acorus calamus
# 基因组大小:470 Mbp
# 物种:Acorus gramineus
# 基因组大小:400 Mbp
# 物种:Lemna minor
# 基因组大小:481 Mbp
# 物种:Lemna minuta
# 基因组大小:360 Mbp
# 物种:Spirodela intermedia
# 基因组大小:160 Mbp
# 物种:Spirodela polyrhiza
# 基因组大小:158 Mbp
# 物种:Wolffia australiana
# 基因组大小:357 Mbp
# 物种:Amorphophallus konjac
# 基因组大小:5700 Mbp
# 物种:Colocasia esculenta
# 基因组大小:2400 Mbp
# 物种:Pinellia pedatisecta
# 基因组大小:1200 Mbp
# 物种:Pistia stratiotes
# 基因组大小:350 Mbp
# 物种:Zostera marina
# 基因组大小:238 Mbp
# 物种:Dioscorea dumetorum
# 基因组大小:322 Mbp
# 物种:Acanthochlamys bracteata
# 基因组大小:204 Mbp
# 物种:Xerophyta viscosa
# 基因组大小:296 Mbp
# 物种:Dioscorea alata
# 基因组大小:480 Mbp
# 物种:Dioscorea dumetorum
# 物种:Silene latifolia
# 基因组大小:2800 Mbp
# 物种:Carnegiea gigantea
# 基因组大小:1300 Mbp
# 物种:Selenicereus undatus
# 基因组大小:1440 Mbp
# 物种:Phytolacca americana
# 基因组大小:1300 Mbp
# 物种:Portulaca amilis
# 基因组大小:400 Mbp
# 物种:Limonium bicolor
# 基因组大小:3170 Mbp
# 物种:Mesembryanthemum crystallinum
# 基因组大小:400 Mbp
# 物种:Nepenthes mirabilis
# 基因组大小:700 Mbp
# 物种:Bougainvillea x buttiana
# 基因组大小:5000 Mbp
# 物种:Hydrangea macrophylla
# 基因组大小:2200 Mbp
# 物种:Camptotheca acuminata
# 基因组大小:516 Mbp
# 物种:Davidia involucrata
# 基因组大小:1169 Mbp
# 物种:Nyssa sinensis
# 基因组大小:1000 Mbp
# 物种:Nyssa yunnanensis
# 基因组大小:1640 Mbp
# 物种:Actinidia arguta
# 基因组大小:650 Mbp
# 物种:Actinidia chinensis
# 基因组大小:758 Mbp
# 物种:Actinidia eriantha
# 基因组大小:745 Mbp
# 物种:Actinidia hemsleyana
# 基因组大小:680 Mbp
# 物种:Actinidia kolomikta
# 基因组大小:640 Mbp
# 物种:Actinidia latifolia
# 基因组大小:640 Mbp
# 物种:Actinidia polygama
# 基因组大小:620 Mbp
# 物种:Actinidia rufa
# 基因组大小:620 Mbp
# 物种:Actinidia zhejiangensis
# 基因组大小:1300 Mbp
# 物种:Arctostaphylos glauca
# 基因组大小:600 Mbp
# 物种:Rhododendron delavayi
# 基因组大小:700 Mbp
# 物种:Rhododendron griersonianum
# 基因组大小:750 Mbp
# 物种:Rhododendron henanense
# 基因组大小:650 Mbp
# 物种:Rhododendron irroratum
# 基因组大小:600 Mbp
# 物种:Rhododendron kiyosumense
# 基因组大小:600 Mbp
# 物种:Rhododendron molle
# 基因组大小:700 Mbp
# 物种:Rhododendron ovatum
# 基因组大小:530 Mbp
# 物种:Rhododendron ripense
# 基因组大小:530 Mbp
# 物种:Rhododendron simsii
# 基因组大小:530 Mbp
# 物种:Rhododendron williamsianum
# 基因组大小:651 Mbp
# 物种:Vaccinium bracteatum
# 基因组大小:580 Mbp
# 物种:Vaccinium caesariense
# 基因组大小:650 Mbp
# 物种:Vaccinium corymbosum
# 基因组大小:500 Mbp
# 物种:Vaccinium darrowii
# 基因组大小:1100 Mbp
# 物种:Vaccinium macrocarpon
# 基因组大小:470 Mbp
# 物种:Vaccinium microcarpum
# 基因组大小:490 Mbp
# 物种:Vaccinium myrtillus
# 基因组大小:600 Mbp
# 物种:Vaccinium oxycoccos
# 基因组大小:590 Mbp
# 物种:Aegiceras corniculatum
# 基因组大小:905 Mbp
# 物种:Primula veris
# 基因组大小:480 Mbp
# 物种:Primula vulgaris
# 基因组大小:470 Mbp
# 物种:Diospyros lotus
# 基因组大小:878 Mbp
# 物种:Diospyros oleifera
# 基因组大小:850 Mbp
# 物种:Diospyros kaki
# 基因组大小:4500 Mbp
# 物种:Argania spinosa
# 基因组大小:573 Mbp
# 物种:Vitellaria paradoxa
# 基因组大小:700 Mbp
# 物种:Cinchona pubescens
# 基因组大小:1100 Mbp
# 物种:Buddleja alternifolia
# 基因组大小:850 Mbp
# 物种:Sesamum indicum
# 基因组大小:357 Mbp
# 物种:Sesamum schinzianum
# 基因组大小:720 Mbp
# 物种:Andrographis paniculata
# 基因组大小:280 Mbp
# 物种:Ruellia speciosa
# 基因组大小:1100 Mbp
# 物种:Strobilanthes cusia
# 基因组大小:840 Mbp
# 物种:Avicennia alba
# 基因组大小:470 Mbp
# 物种:Avicennia germinans
# 基因组大小:700 Mbp
# 物种:Avicennia marina
# 基因组大小:460 Mbp
# 物种:Avicennia officinalis
# 基因组大小:460 Mbp
# 物种:Avicennia rumphiana
# 基因组大小:480 Mbp
# 物种:Forsythia suspensa
# 基因组大小:701 Mbp
# 物种:Fraxinus excelsior
# 基因组大小:880 Mbp
# 物种:Fraxinus pennsylvanica
# 基因组大小:800 Mbp
# 物种:Jasminum sambac
# 基因组大小:510 Mbp
# 物种:Olea europaea
# 基因组大小:1380 Mbp
# 物种:Osmanthus fragrans
# 基因组大小:730 Mbp
# 物种:Syringa oblata
# 基因组大小:1270 Mbp
# 物种:Dorcoceras hygrometrica
# 基因组大小:1690 Mbp
# 物种:Primulina eburnea
# 基因组大小:870 Mbp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\legion\Desktop\github_webpage\content\post\selenium学习笔记1\index.ipynb Cell 17 in 1
#      <a href='vscode-notebook-cell:/c%3A/Users/legion/Desktop/github_webpage/content/post/selenium%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B01/index.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a> for leaf in leaves:
#      <a href='vscode-notebook-cell:/c%3A/Users/legion/Desktop/github_webpage/content/post/selenium%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B01/index.ipynb#X22sZmlsZQ%3D%3D?line=16'>17</a>     driver.execute_script(f"arguments[0].scrollIntoView();",leaf)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/legion/Desktop/github_webpage/content/post/selenium%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B01/index.ipynb#X22sZmlsZQ%3D%3D?line=17'>18</a>     ActionChains(driver).move_to_element(leaf).perform()
#      <a href='vscode-notebook-cell:/c%3A/Users/legion/Desktop/github_webpage/content/post/selenium%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B01/index.ipynb#X22sZmlsZQ%3D%3D?line=18'>19</a>     wait = WebDriverWait(driver, timeout=10,ignored_exceptions=TimeoutException)
#      <a href='vscode-notebook-cell:/c%3A/Users/legion/Desktop/github_webpage/content/post/selenium%E5%AD%A6%E4%B9%A0%E7%AC%94%E8%AE%B01/index.ipynb#X22sZmlsZQ%3D%3D?line=19'>20</a>     element = wait.until(EC.presence_of_element_located((By.CLASS_NAME, 'd3-tip')))
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\action_chains.py:87, in ActionChains.perform(self)
#      85 def perform(self):
#      86     """Performs all stored actions."""
# ---> 87     self.w3c_actions.perform()
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\common\actions\action_builder.py:91, in ActionBuilder.perform(self)
#      89         enc["actions"].append(encoded)
#      90         device.actions = []
# ---> 91 self.driver.execute(Command.W3C_ACTIONS, enc)
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     341     elif "sessionId" not in params:
#     342         params["sessionId"] = self.session_id
# --> 344 response = self.command_executor.execute(driver_command, params)
#     345 if response:
#     346     self.error_handler.check_response(response)
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:290, in RemoteConnection.execute(self, command, params)
#     288 data = utils.dump_json(params)
#     289 url = f"{self._url}{path}"
# --> 290 return self._request(command_info[0], url, body=data)
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\selenium\webdriver\remote\remote_connection.py:311, in RemoteConnection._request(self, method, url, body)
#     308     body = None
#     310 if self.keep_alive:
# --> 311     response = self._conn.request(method, url, body=body, headers=headers)
#     312     statuscode = response.status
#     313 else:
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:78, in RequestMethods.request(self, method, url, fields, headers, **urlopen_kw)
#      74     return self.request_encode_url(
#      75         method, url, fields=fields, headers=headers, **urlopen_kw
#      76     )
#      77 else:
# ---> 78     return self.request_encode_body(
#      79         method, url, fields=fields, headers=headers, **urlopen_kw
#      80     )
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\request.py:170, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     167 extra_kw["headers"].update(headers)
#     168 extra_kw.update(urlopen_kw)
# --> 170 return self.urlopen(method, url, **extra_kw)
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\poolmanager.py:376, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     374     response = conn.urlopen(method, url, **kw)
#     375 else:
# --> 376     response = conn.urlopen(method, u.request_uri, **kw)
#     378 redirect_location = redirect and response.get_redirect_location()
#     379 if not redirect_location:
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File c:\Users\legion\AppData\Local\Programs\Python\Python311\Lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
